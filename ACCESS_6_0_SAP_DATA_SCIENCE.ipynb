# %% [markdown]
# <a href="https://colab.research.google.com/github/osineyeabraham/Data-science-ACCESS-6.0-SAP/blob/main/ACCESS_6_0_SAP_DATA_SCIENCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import json
from pandas import json_normalize

# Read the JSON file content into a Python object
with open("/budgetwise-personal-finance-dataset-metadata (1).json", 'r') as f:
    json_data = json.load(f)

# Flatten the JSON data into a DataFrame
df_fin = json_normalize(json_data)

# %%
df_fin.head()
# Out:
#                                        alternateName  \
# 0  Transactions data with issues for cleaning, pr...
#
#                            conformsTo  \
# 0  http://mlcommons.org/croissant/1.0
#
#                                         distribution  \
# 0  [{'contentUrl': 'https://www.kaggle.com/api/v1...
#
#                                            recordSet  version  \
# 0  [{'field': [{'dataType': ['sc:Text'], 'source'...        2
#
#                                             keywords  isAccessibleForFree  \
# 0  [subject > people and society > business > fin...                 True
#
#                                         thumbnailUrl            dateModified  \
# 0  https://storage.googleapis.com/kaggle-datasets...  2025-09-29T14:30:50.82
#
#             datePublished  ... includedInDataCatalog.name  \
# 0  2025-09-29T14:13:39.59  ...                     Kaggle
#
#   includedInDataCatalog.url creator.@type       creator.name  \
# ...

# %%
df_fin.tail()
# Out:
#                                        alternateName  \
# 0  Transactions data with issues for cleaning, pr...
#
#                            conformsTo  \
# 0  http://mlcommons.org/croissant/1.0
#
#                                         distribution  \
# 0  [{'contentUrl': 'https://www.kaggle.com/api/v1...
#
#                                            recordSet  version  \
# 0  [{'field': [{'dataType': ['sc:Text'], 'source'...        2
#
#                                             keywords  isAccessibleForFree  \
# 0  [subject > people and society > business > fin...                 True
#
#                                         thumbnailUrl            dateModified  \
# 0  https://storage.googleapis.com/kaggle-datasets...  2025-09-29T14:30:50.82
#
#             datePublished  ... includedInDataCatalog.name  \
# 0  2025-09-29T14:13:39.59  ...                     Kaggle
#
#   includedInDataCatalog.url creator.@type       creator.name  \
# ...

# %%
df_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 67 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   alternateName                          1 non-null      object
#  1   conformsTo                             1 non-null      object
#  2   distribution                           1 non-null      object
#  3   recordSet                              1 non-null      object
#  4   version                                1 non-null      int64
#  5   keywords                               1 non-null      object
#  6   isAccessibleForFree                    1 non-null      bool
#  7   thumbnailUrl                           1 non-null      object
#  8   dateModified                           1 non-null      object
#  9   datePublished                          1 non-null      object
#  10  @type                                  1 non-null      object
# ...

# %%
df_fin.describe()
# Out:
#        version
# count      1.0
# mean       2.0
# std        NaN
# min        2.0
# 25%        2.0
# 50%        2.0
# 75%        2.0
# max        2.0

# %%
df_fin.columns
# Out:
# Index(['alternateName', 'conformsTo', 'distribution', 'recordSet', 'version',
#        'keywords', 'isAccessibleForFree', 'thumbnailUrl', 'dateModified',
#        'datePublished', '@type', 'name', 'url', 'description',
#        '@context.@language', '@context.@vocab', '@context.citeAs',
#        '@context.column', '@context.conformsTo', '@context.cr',
#        '@context.data.@id', '@context.data.@type', '@context.dataBiases',
#        '@context.dataCollection', '@context.dataType.@id',
#        '@context.dataType.@type', '@context.dct', '@context.extract',
#        '@context.field', '@context.fileProperty', '@context.fileObject',
#        '@context.fileSet', '@context.format', '@context.includes',
#        '@context.isEnumeration', '@context.isLiveDataset', '@context.jsonPath',
#        '@context.key', '@context.md5', '@context.parentField', '@context.path',
#        '@context.personalSensitiveInformation', '@context.recordSet',
# ...
